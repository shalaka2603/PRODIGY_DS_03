# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import accuracy_score, classification_report
from sklearn.preprocessing import LabelEncoder

# %%
df = pd.read_excel("/content/drive/MyDrive/ProdigyInternship/bank-full.xlsx")
df.head()
# Out:
#    age           job  marital  education default  balance housing loan  \
# 0   58    management  married   tertiary      no     2143     yes   no
# 1   44    technician   single  secondary      no       29     yes   no
# 2   33  entrepreneur  married  secondary      no        2     yes  yes
# 3   47   blue-collar  married    unknown      no     1506     yes   no
# 4   33       unknown   single    unknown      no        1      no   no
#
#    contact  day month  duration  campaign  pdays  previous poutcome   y
# 0  unknown    5   may       261         1     -1         0  unknown  no
# 1  unknown    5   may       151         1     -1         0  unknown  no
# 2  unknown    5   may        76         1     -1         0  unknown  no
# 3  unknown    5   may        92         1     -1         0  unknown  no
# 4  unknown    5   may       198         1     -1         0  unknown  no

# %%
x = df.drop(["balance", "housing", "loan", "contact", "day", "month", "duration", "campaign", "pdays", "previous", "poutcome"], axis=1)
print(x)
# Out:
#        age           job   marital  education default    y
# 0       58    management   married   tertiary      no   no
# 1       44    technician    single  secondary      no   no
# 2       33  entrepreneur   married  secondary      no   no
# 3       47   blue-collar   married    unknown      no   no
# 4       33       unknown    single    unknown      no   no
# ...    ...           ...       ...        ...     ...  ...
# 45206   51    technician   married   tertiary      no  yes
# 45207   71       retired  divorced    primary      no  yes
# 45208   72       retired   married  secondary      no  yes
# 45209   57   blue-collar   married  secondary      no   no
# 45210   37  entrepreneur   married  secondary      no   no
#
# [45211 rows x 6 columns]

# %%
x.isnull().sum()
# Out:
# age          0
# job          0
# marital      0
# education    0
# default      0
# y            0
# dtype: int64

# %%
x.duplicated().sum()
# Out:
# 39586

# %%
data = x.drop_duplicates()
data.duplicated().sum()
# Out:
# 0

# %%
data.shape
# Out:
# (5625, 6)

# %%
def outcome(row):
  if row['y'] == "yes":
    return 1
  else:
    return 0

# %%
data['default'] = data.apply(outcome, axis=1)
data['y'] = data.apply(outcome, axis=1)
print(data)
# Out:
#           age           job   marital  education  default  y
# 0        58.0    management   married   tertiary        0  0
# 1        44.0    technician    single  secondary        0  0
# 2        33.0  entrepreneur   married  secondary        0  0
# 3        47.0   blue-collar   married    unknown        0  0
# 4        33.0       unknown    single    unknown        0  0
# ...       ...           ...       ...        ...      ... ..
# 45150    65.0    management   married    unknown        0  0
# 45191    75.0       retired  divorced   tertiary        0  0
# 45197    36.0    management    single  secondary        0  0
# 45204    73.0       retired   married  secondary        0  0
# default   NaN           NaN       NaN        NaN        0  0
#
# [5626 rows x 6 columns]
# <ipython-input-26-69eea1a6c4eb>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# ...

# %%
le = LabelEncoder()
le.fit(data['job'])
data['job'] = le.transform(data['job'])

le = LabelEncoder()
le.fit(data['marital'])
data['marital'] = le.transform(data['marital'])

le = LabelEncoder()
le.fit(data['education'])
data['education'] = le.transform(data['education'])

print(data)
# Out:
#           age  job  marital  education  default  y
# 0        58.0    4        1          2        0  0
# 1        44.0    9        2          1        0  0
# 2        33.0    2        1          1        0  0
# 3        47.0    1        1          3        0  0
# 4        33.0   11        2          3        0  0
# ...       ...  ...      ...        ...      ... ..
# 45150    65.0    4        1          3        0  0
# 45191    75.0    5        0          2        0  0
# 45197    36.0    4        2          1        0  0
# 45204    73.0    5        1          1        0  0
# default   NaN   12        3          4        0  0
#
# [5626 rows x 6 columns]
# <ipython-input-33-e10d789aa337>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# ...

# %%
data = data.fillna(0)
Y = data["y"].astype(int)
X = data.drop(["y"], axis = 1)

# %%
print(X)
# Out:
#           age  job  marital  education  default
# 0        58.0    4        1          2        0
# 1        44.0    9        2          1        0
# 2        33.0    2        1          1        0
# 3        47.0    1        1          3        0
# 4        33.0   11        2          3        0
# ...       ...  ...      ...        ...      ...
# 45150    65.0    4        1          3        0
# 45191    75.0    5        0          2        0
# 45197    36.0    4        2          1        0
# 45204    73.0    5        1          1        0
# default   0.0   12        3          4        0
#
# [5626 rows x 5 columns]

# %%
print(Y)
# Out:
# 0          0
# 1          0
# 2          0
# 3          0
# 4          0
#           ..
# 45150      0
# 45191      0
# 45197      0
# 45204      0
# default    0
# Name: y, Length: 5626, dtype: int64

# %%
x_train, x_test, y_train, y_test = train_test_split(X, Y, random_state=0, test_size=0.3)

# %%
clf = DecisionTreeClassifier(random_state=2)

# %%
clf.fit(x_train, y_train)
# Out:
# DecisionTreeClassifier(random_state=2)

# %%
y_pred = clf.predict(x_test)

# %%
accuracy = accuracy_score(y_test, y_pred)
print("Accuracy:", accuracy)
# Out:
# Accuracy: 1.0

# %%
print("Classification Report:\n", classification_report(y_test, y_pred))
# Out:
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00      1688
#
#     accuracy                           1.00      1688
#    macro avg       1.00      1.00      1.00      1688
# weighted avg       1.00      1.00      1.00      1688
